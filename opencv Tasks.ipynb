# %%
import cv2
import numpy as np
import matplotlib.image,matplotlib.pyplot as plt

# %%
#cv prints by default a BGR photo (use cvt func. to use RGB)
img=cv2.imread("the-house-of-the-dead_16.jpg")
RGB_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
cv2.imshow("img", img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
img1=plt.imread("the-house-of-the-dead_16.jpg") #Reading img by cv2& printing w/ plt is dumb...don't be Dumb :)
plt.imshow(img1) #imshow is an attribute of .pyplot (Not .image)

# %% [markdown]
# ## Task 2 Read a video

# %%
yu=cv2.VideoCapture("Yuzuru Hanyu 2019 Canada.mp4")
if (yu.isOpened()== False):
    print("nah it's not opened try another Code you stoopid")
    
while(yu.isOpened()):
    ret, frame = yu.read()
    if ret == True:
        cv2.imshow("frame",frame)
        if cv2.waitKey(1)  == ord('q'): #0xFF
            break
    else:
	    break
yu.release()
cv2.destroyAllWindows()
# Out:
# ...
#    QT_AUTO_SCREEN_SCALE_FACTOR to enable platform plugin controlled per-screen factors.
#    QT_SCREEN_SCALE_FACTORS to set per-screen DPI.
#    QT_SCALE_FACTOR to set the application global scale factor.
# QObject::moveToThread: Current thread (0x561728fc1050) is not the object's thread (0x5617291853d0).
# Cannot move to target thread (0x561728fc1050)
#
# QObject::moveToThread: Current thread (0x561728fc1050) is not the object's thread (0x5617291853d0).
# Cannot move to target thread (0x561728fc1050)
#
# QObject::moveToThread: Current thread (0x561728fc1050) is not the object's thread (0x5617291853d0).
# Cannot move to target thread (0x561728fc1050)
#
# QObject::moveToThread: Current thread (0x561728fc1050) is not the object's thread (0x5617291853d0).
# Cannot move to target thread (0x561728fc1050)
#
# QObject::moveToThread: Current thread (0x561728fc1050) is not the object's thread (0x5617291853d0).
# Cannot move to target thread (0x561728fc1050)
#
# ...

# %% [markdown]
# ## Task3 resize, convert to grayscale, save an image

# %%
read_img=cv2.imread("the-house-of-the-dead_16.jpg") # zero will make it greyScale too
Gray=cv2.cvtColor(read_img, cv2.COLOR_RGB2GRAY)
cv2.imshow("img", Gray)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
#grayscaling, resizing, saving the img
read_img=cv2.imread("the-house-of-the-dead_16.jpg",0) 
new_width = 460
new_height = 280
new_dimensions= (new_width, new_height)
img=cv2.resize(read_img, new_dimensions, cv2.INTER_LINEAR) #dimensions in tuple
cv2.imwrite("saved.jpg",img)
cv2.imshow("img", img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ## Task4 read live cam, save it

# %%
record=cv2.VideoCapture(0)
if (record.isOpened()== False):
    print("nah it's not opened, type another Code, stoopid")

frame_width = int(record.get(3)) #can't understand why if it's different number it won't be saved
frame_height = int(record.get(4))
size = (frame_width, frame_height)  
video=cv2.VideoWriter("saved.mp4",cv2.VideoWriter_fourcc(*'mp4v'),25,size) #fps=25

while(record.isOpened()):
    ret, frame = record.read()
    if ret == True:
        video.write(frame)
        gray = cv2.cvtColor(frame, cv2.COLOR_RGB2GRAY)
        cv2.imshow("frame",gray)
        
        if cv2.waitKey(1) == ord('q'): #0xFF
            break
    else:
	    break

record.release()
video.release()
cv2.destroyAllWindows()
    #I WANT TO SAVE IT AS I RENDERED IT :'(
# Out:
# QObject::moveToThread: Current thread (0x56259c659360) is not the object's thread (0x56259c86d320).
# Cannot move to target thread (0x56259c659360)
#
# QObject::moveToThread: Current thread (0x56259c659360) is not the object's thread (0x56259c86d320).
# Cannot move to target thread (0x56259c659360)
#
# QObject::moveToThread: Current thread (0x56259c659360) is not the object's thread (0x56259c86d320).
# Cannot move to target thread (0x56259c659360)
#
# QObject::moveToThread: Current thread (0x56259c659360) is not the object's thread (0x56259c86d320).
# Cannot move to target thread (0x56259c659360)
#
# QObject::moveToThread: Current thread (0x56259c659360) is not the object's thread (0x56259c86d320).
# Cannot move to target thread (0x56259c659360)
#
# QObject::moveToThread: Current thread (0x56259c659360) is not the object's thread (0x56259c86d320).
# Cannot move to target thread (0x56259c659360)
#
# ...

# %% [markdown]
# ## Task5 find contors

# %%
image = cv2.imread('images.jpg')
cv2.waitKey(0)
  
# Grayscale
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
  
# Find Canny edges
edged = cv2.Canny(gray, 30, 200)
cv2.waitKey(0)
  
# Finding Contours
# Use a copy of the image e.g. edged.copy()
# since findContours alters the image
contours, hierarchy = cv2.findContours(edged, 
    cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_NONE)
  
cv2.imshow('Canny Edges After Contouring', edged)
cv2.waitKey(0)
  
print("Number of Contours found = " + str(len(contours)))
  
# Draw all contours
# -1 signifies drawing all contours
cv2.drawContours(image, contours, -1, (0, 255, 0), 3)
  
cv2.imshow('Contours', image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
ret, thresh = cv2.threshold(img_gray, 150, 255, cv2.THRESH_BINARY)
cv2.imwrite('HandLines1.jpg', thresh)

contours, hierarchy = cv2.findContours(image=thresh, mode=cv2.RETR_TREE, method=cv2.CHAIN_APPROX_NONE)
image_copy = img.copy()

cv2.drawContours(image=image_copy, contours=contours, contourIdx=-1, color=(0, 255, 0), thickness=2, lineType=cv2.LINE_AA)
cv2.imshow('None approximation', image_copy)

cv2.waitKey(0)
cv2.imwrite('HandLines1.jpg', image_copy)
cv2.destroyAllWindows()

# %% [markdown]
# ## Task6 detect Edges

# %%
while True:
    edges = cv2.Canny(img_gray, threshold1=50, threshold2=300)
    cv2.imshow("edges", edges)
    if cv2.waitKey(1) == ord("q"):
        break
cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# ## task7 install sikit img, load 5 images, resize them to same dimensions

# %%
l=['HandLines1.jpg','istockphoto-1368965646-170667a.jpg','800px-Paume_de_main.jpeg']
images=[]
for i in l:
    img=cv2.imread(i)
    img=cv2.resize(img,(500,500))
    images.append(img)
for image in images:
    cv.imshow("image ", image)
    cv2.waitKey()
    cv2.destroyAllWindows()

# %% [markdown]
# ## Task8 face detection opencv

# %%
import cv2
import os

cascPath=os.path.dirname(cv2.__file__)+"/data/haarcascade_frontalface_default.xml"
faceCascade = cv2.CascadeClassifier(cascPath)

video_capture = cv2.VideoCapture(0)

while True:
    # Capture frame-by-frame
    ret, frames = video_capture.read()

    gray = cv2.cvtColor(frames, cv2.COLOR_BGR2GRAY)

    faces = faceCascade.detectMultiScale(
        gray,
        scaleFactor=1.1,
        minNeighbors=5,
        minSize=(30, 30),
        flags=cv2.CASCADE_SCALE_IMAGE
    )

    # Draw a rectangle around the faces
    for (x, y, w, h) in faces:
        cv2.rectangle(frames, (x, y), (x+w, y+h), (0, 255, 0), 2)

    # Display the resulting frame
    cv2.imshow('Video', frames)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break
video_capture.release()
cv2.destroyAllWindows()

# %%
haar_cascade_face  = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')
# haar_cascade_face = cv2.CascadeClassifier('data/haarcascade/haarcascade_frontalface_default.xml')
def detect_faces(cascade, test_image, scaleFactor = 1.1):
    # create a copy of the image to prevent any changes to the original one.
    image_copy = test_image.copy()

    #convert the test image to gray scale as opencv face detector expects gray images
    gray_image = cv2.cvtColor(image_copy, cv2.COLOR_BGR2GRAY)

    # Applying the haar classifier to detect faces
    faces_rect = cascade.detectMultiScale(gray_image, scaleFactor=scaleFactor, minNeighbors=5)

    for (x, y, w, h) in faces_rect:
        cv2.rectangle(image_copy, (x, y), (x+w, y+h), (0, 255, 0), 15)

    return image_copy

def convertToRGB(image):
    return cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

import matplotlib.pyplot as plt
#loading image
test_image2 = cv2.imread('istockphoto-1368965646-170667a.jpg')

#call the function to detect faces
faces = detect_faces(haar_cascade_face, test_image2)

#convert to RGB and display image
plt.imshow(convertToRGB(faces))
